# %% [markdown]
# ![rmotr](https://user-images.githubusercontent.com/7065401/52071918-bda15380-2562-11e9-828c-7f95297e4a82.png)
# <hr style="margin-bottom: 40px;">
#
# # Pandas DataFrame exercises

# %%
# Import the numpy package under the name np
import numpy as np

# Import the pandas package under the name pd
import pandas as pd

# Print the pandas version and the configuration
print(pd.__version__)
# Out:
# 2.0.3

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
#
# ## DataFrame creation

# %% [markdown]
# ---
# Create an empty pandas DataFrame

# %%
# your code goes here

# %%
df = pd.DataFrame()
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ---
# Create a pandas DataFrame with None data None index None columns

# %%
# your code goes here

# %%
df = pd.DataFrame(data=[None], index=[None], columns=[None])
df
# Out:
#       None
# None  None

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
#
# ## Marvel_example
#
# <img width=400 src="https://cdn.dribbble.com/users/4678/screenshots/1986600/avengers.png"></img>

# %%
# given data

col_names = [
    "name",
    "gender",
    "first_appearance",
    "superpower",
    "team",
    "origin",
    "popularity_score",
    "status",
]
marvel_data = [
    [
        "Spider-Man",
        "male",
        1962,
        "Wall-crawling, super strength",
        "Avengers",
        "New York",
        9.8,
        "active",
    ],
    [
        "Captain America",
        "male",
        1941,
        "Super soldier strength",
        "Avengers",
        "World War II",
        9.6,
        "active",
    ],
    [
        "Wolverine",
        "male",
        1974,
        "Regeneration, claws",
        "X-Men",
        "Canada",
        9.5,
        "active",
    ],
    [
        "Iron Man",
        "male",
        1963,
        "Genius-level intellect, powered armor",
        "Avengers",
        "New York",
        9.7,
        "deceased",
    ],
    [
        "Thor",
        "male",
        1963,
        "Godly strength, Mjölnir",
        "Avengers",
        "Asgard",
        9.8,
        "active",
    ],
    [
        "Thing",
        "male",
        1961,
        "Rocky skin, super strength",
        "Fantastic Four",
        "New York",
        8.5,
        "active",
    ],
    [
        "Mister Fantastic",
        "male",
        1961,
        "Elastic body",
        "Fantastic Four",
        "New York",
        8.8,
        "active",
    ],
    [
        "Hulk",
        "male",
        1962,
        "Super strength, rage-induced transformation",
        "Avengers",
        "New York",
        9.2,
        "active",
    ],
    [
        "Beast",
        "male",
        1963,
        "Super strength, agility",
        "X-Men",
        "Illinois",
        8.3,
        "active",
    ],
    [
        "Invisible Woman",
        "female",
        1961,
        "Invisibility, force fields",
        "Fantastic Four",
        "New York",
        8.9,
        "active",
    ],
    ["Storm", "female", 1975, "Weather manipulation", "X-Men", "Kenya", 9.1, "active"],
    ["Namor", "male", 1939, "Aquatic abilities", "X-Men", "Atlantis", 7.9, "active"],
    ["Hawkeye", "male", 1964, "Expert archer", "Avengers", "Iowa", 7.8, "active"],
    [
        "Daredevil",
        "male",
        1964,
        "Enhanced senses, martial arts",
        "Defenders",
        "New York",
        8.7,
        "active",
    ],
    [
        "Doctor Strange",
        "male",
        1963,
        "Master of mystic arts",
        "Defenders",
        "New York",
        9.4,
        "active",
    ],
    [
        "Hank Pym",
        "male",
        1962,
        "Size manipulation",
        "Avengers",
        "New York",
        8.0,
        "retired",
    ],
    [
        "Scarlet Witch",
        "female",
        1964,
        "Reality manipulation",
        "Avengers",
        "Sokovia",
        9.3,
        "active",
    ],
    [
        "Wasp",
        "female",
        1963,
        "Size manipulation, flight",
        "Avengers",
        "New York",
        8.1,
        "active",
    ],
    [
        "Black Widow",
        "female",
        1964,
        "Expert spy, martial artist",
        "Avengers",
        "Russia",
        9.0,
        "deceased",
    ],
    [
        "Vision",
        "male",
        1968,
        "Density manipulation",
        "Avengers",
        "Synthoid",
        8.9,
        "active",
    ],
]

# %% [markdown]
# ---
# Create a `marvel_df` pandas DataFrame with the given `marvel_data`  with `col_names`

# %%
# your code goes here

# %%
marvel_df = pd.DataFrame(marvel_data, columns=col_names)
marvel_df
# Out:
#                 name  gender  first_appearance  \
# 0         Spider-Man    male              1962
# 1    Captain America    male              1941
# 2          Wolverine    male              1974
# 3           Iron Man    male              1963
# 4               Thor    male              1963
# 5              Thing    male              1961
# 6   Mister Fantastic    male              1961
# 7               Hulk    male              1962
# 8              Beast    male              1963
# 9    Invisible Woman  female              1961
# 10             Storm  female              1975
# 11             Namor    male              1939
# 12           Hawkeye    male              1964
# 13         Daredevil    male              1964
# 14    Doctor Strange    male              1963
# 15          Hank Pym    male              1962
# 16     Scarlet Witch  female              1964
# 17              Wasp  female              1963
# 18       Black Widow  female              1964
# 19            Vision    male              1968
#
#                                      superpower            team        origin  \
# 0                 Wall-crawling, super strength        Avengers      New York
# 1                        Super soldier strength        Avengers  World War II
# 2                           Regeneration, claws           X-Men        Canada
# 3         Genius-level intellect, powered armor        Avengers      New York
# 4                       Godly strength, Mjölnir        Avengers        Asgard
# 5                    Rocky skin, super strength  Fantastic Four      New York
# 6                                  Elastic body  Fantastic Four      New York
# 7   Super strength, rage-induced transformation        Avengers      New York
# 8                       Super strength, agility           X-Men      Illinois
# 9                    Invisibility, force fields  Fantastic Four      New York
# 10                         Weather manipulation           X-Men         Kenya
# 11                            Aquatic abilities           X-Men      Atlantis
# 12                                Expert archer        Avengers          Iowa
# 13                Enhanced senses, martial arts       Defenders      New York
# 14                        Master of mystic arts       Defenders      New York
# 15                            Size manipulation        Avengers      New York
# 16                         Reality manipulation        Avengers       Sokovia
# 17                    Size manipulation, flight        Avengers      New York
# 18                   Expert spy, martial artist        Avengers        Russia
# 19                         Density manipulation        Avengers      Synthoid
#
#     popularity_score    status
# 0                9.8    active
# 1                9.6    active
# 2                9.5    active
# 3                9.7  deceased
# 4                9.8    active
# 5                8.5    active
# 6                8.8    active
# 7                9.2    active
# 8                8.3    active
# 9                8.9    active
# 10               9.1    active
# 11               7.9    active
# 12               7.8    active
# 13               8.7    active
# 14               9.4    active
# 15               8.0   retired
# 16               9.3    active
# 17               8.1    active
# 18               9.0  deceased
# 19               8.9    active

# %%
# another way
marvel_df = pd.DataFrame(marvel_data)
marvel_df.columns = col_names
marvel_df
# Out:
#                 name  gender  first_appearance  \
# 0         Spider-Man    male              1962
# 1    Captain America    male              1941
# 2          Wolverine    male              1974
# 3           Iron Man    male              1963
# 4               Thor    male              1963
# 5              Thing    male              1961
# 6   Mister Fantastic    male              1961
# 7               Hulk    male              1962
# 8              Beast    male              1963
# 9    Invisible Woman  female              1961
# 10             Storm  female              1975
# 11             Namor    male              1939
# 12           Hawkeye    male              1964
# 13         Daredevil    male              1964
# 14    Doctor Strange    male              1963
# 15          Hank Pym    male              1962
# 16     Scarlet Witch  female              1964
# 17              Wasp  female              1963
# 18       Black Widow  female              1964
# 19            Vision    male              1968
#
#                                      superpower            team        origin  \
# 0                 Wall-crawling, super strength        Avengers      New York
# 1                        Super soldier strength        Avengers  World War II
# 2                           Regeneration, claws           X-Men        Canada
# 3         Genius-level intellect, powered armor        Avengers      New York
# 4                       Godly strength, Mjölnir        Avengers        Asgard
# 5                    Rocky skin, super strength  Fantastic Four      New York
# 6                                  Elastic body  Fantastic Four      New York
# 7   Super strength, rage-induced transformation        Avengers      New York
# 8                       Super strength, agility           X-Men      Illinois
# 9                    Invisibility, force fields  Fantastic Four      New York
# 10                         Weather manipulation           X-Men         Kenya
# 11                            Aquatic abilities           X-Men      Atlantis
# 12                                Expert archer        Avengers          Iowa
# 13                Enhanced senses, martial arts       Defenders      New York
# 14                        Master of mystic arts       Defenders      New York
# 15                            Size manipulation        Avengers      New York
# 16                         Reality manipulation        Avengers       Sokovia
# 17                    Size manipulation, flight        Avengers      New York
# 18                   Expert spy, martial artist        Avengers        Russia
# 19                         Density manipulation        Avengers      Synthoid
#
#     popularity_score    status
# 0                9.8    active
# 1                9.6    active
# 2                9.5    active
# 3                9.7  deceased
# 4                9.8    active
# 5                8.5    active
# 6                8.8    active
# 7                9.2    active
# 8                8.3    active
# 9                8.9    active
# 10               9.1    active
# 11               7.9    active
# 12               7.8    active
# 13               8.7    active
# 14               9.4    active
# 15               8.0   retired
# 16               9.3    active
# 17               8.1    active
# 18               9.0  deceased
# 19               8.9    active

# %% [markdown]
# ---
# show its columns only

# %%
# your code goes here

# %%
marvel_df.columns
# Out:
# Index(['name', 'gender', 'first_appearance', 'superpower', 'team', 'origin',
#        'popularity_score', 'status'],
#       dtype='object')

# %% [markdown]
# ---
# show the row count of this dataframe

# %%
# your code goes here

# %%
marvel_df.shape[0]
# Out:
# 20

# %% [markdown]
# ---
# set name column to be index of this dataframe

# %%
# your code goes here

# %%
marvel_df = marvel_df.set_index("name")
marvel_df
# Out:
#                   gender  first_appearance  \
# name
# Spider-Man          male              1962
# Captain America     male              1941
# Wolverine           male              1974
# Iron Man            male              1963
# Thor                male              1963
# Thing               male              1961
# Mister Fantastic    male              1961
# Hulk                male              1962
# Beast               male              1963
# Invisible Woman   female              1961
# Storm             female              1975
# Namor               male              1939
# Hawkeye             male              1964
# Daredevil           male              1964
# Doctor Strange      male              1963
# Hank Pym            male              1962
# Scarlet Witch     female              1964
# Wasp              female              1963
# Black Widow       female              1964
# Vision              male              1968
#
#                                                    superpower            team  \
# name
# Spider-Man                      Wall-crawling, super strength        Avengers
# Captain America                        Super soldier strength        Avengers
# Wolverine                                 Regeneration, claws           X-Men
# Iron Man                Genius-level intellect, powered armor        Avengers
# Thor                                  Godly strength, Mjölnir        Avengers
# Thing                              Rocky skin, super strength  Fantastic Four
# Mister Fantastic                                 Elastic body  Fantastic Four
# Hulk              Super strength, rage-induced transformation        Avengers
# Beast                                 Super strength, agility           X-Men
# Invisible Woman                    Invisibility, force fields  Fantastic Four
# Storm                                    Weather manipulation           X-Men
# Namor                                       Aquatic abilities           X-Men
# Hawkeye                                         Expert archer        Avengers
# Daredevil                       Enhanced senses, martial arts       Defenders
# Doctor Strange                          Master of mystic arts       Defenders
# Hank Pym                                    Size manipulation        Avengers
# Scarlet Witch                            Reality manipulation        Avengers
# Wasp                                Size manipulation, flight        Avengers
# Black Widow                        Expert spy, martial artist        Avengers
# Vision                                   Density manipulation        Avengers
#
#                         origin  popularity_score    status
# name
# Spider-Man            New York               9.8    active
# Captain America   World War II               9.6    active
# Wolverine               Canada               9.5    active
# Iron Man              New York               9.7  deceased
# Thor                    Asgard               9.8    active
# Thing                 New York               8.5    active
# Mister Fantastic      New York               8.8    active
# Hulk                  New York               9.2    active
# Beast                 Illinois               8.3    active
# Invisible Woman       New York               8.9    active
# Storm                    Kenya               9.1    active
# Namor                 Atlantis               7.9    active
# Hawkeye                   Iowa               7.8    active
# Daredevil             New York               8.7    active
# Doctor Strange        New York               9.4    active
# Hank Pym              New York               8.0   retired
# Scarlet Witch          Sokovia               9.3    active
# Wasp                  New York               8.1    active
# Black Widow             Russia               9.0  deceased
# Vision                Synthoid               8.9    active

# %% [markdown]
# ---
# Drop 'Namor' and 'Hank Pym' rows - do not save onto original. just show the result

# %%
# your code goes here

# %%
marvel_df.drop(["Namor", "Hank Pym"])
# Out:
#                   gender  first_appearance  \
# name
# Spider-Man          male              1962
# Captain America     male              1941
# Wolverine           male              1974
# Iron Man            male              1963
# Thor                male              1963
# Thing               male              1961
# Mister Fantastic    male              1961
# Hulk                male              1962
# Beast               male              1963
# Invisible Woman   female              1961
# Storm             female              1975
# Hawkeye             male              1964
# Daredevil           male              1964
# Doctor Strange      male              1963
# Scarlet Witch     female              1964
# Wasp              female              1963
# Black Widow       female              1964
# Vision              male              1968
#
#                                                    superpower            team  \
# name
# Spider-Man                      Wall-crawling, super strength        Avengers
# Captain America                        Super soldier strength        Avengers
# Wolverine                                 Regeneration, claws           X-Men
# Iron Man                Genius-level intellect, powered armor        Avengers
# Thor                                  Godly strength, Mjölnir        Avengers
# Thing                              Rocky skin, super strength  Fantastic Four
# Mister Fantastic                                 Elastic body  Fantastic Four
# Hulk              Super strength, rage-induced transformation        Avengers
# Beast                                 Super strength, agility           X-Men
# Invisible Woman                    Invisibility, force fields  Fantastic Four
# Storm                                    Weather manipulation           X-Men
# Hawkeye                                         Expert archer        Avengers
# Daredevil                       Enhanced senses, martial arts       Defenders
# Doctor Strange                          Master of mystic arts       Defenders
# Scarlet Witch                            Reality manipulation        Avengers
# Wasp                                Size manipulation, flight        Avengers
# Black Widow                        Expert spy, martial artist        Avengers
# Vision                                   Density manipulation        Avengers
#
#                         origin  popularity_score    status
# name
# Spider-Man            New York               9.8    active
# Captain America   World War II               9.6    active
# Wolverine               Canada               9.5    active
# Iron Man              New York               9.7  deceased
# Thor                    Asgard               9.8    active
# Thing                 New York               8.5    active
# Mister Fantastic      New York               8.8    active
# Hulk                  New York               9.2    active
# Beast                 Illinois               8.3    active
# Invisible Woman       New York               8.9    active
# Storm                    Kenya               9.1    active
# Hawkeye                   Iowa               7.8    active
# Daredevil             New York               8.7    active
# Doctor Strange        New York               9.4    active
# Scarlet Witch          Sokovia               9.3    active
# Wasp                  New York               8.1    active
# Black Widow             Russia               9.0  deceased
# Vision                Synthoid               8.9    active

# %% [markdown]
# ---
# Drop 'superpower' column - do not save onto original. just show the result

# %%
# your code goes here

# %%
marvel_df.drop("superpower", axis=1)
# Out:
#                   gender  first_appearance            team        origin  \
# name
# Spider-Man          male              1962        Avengers      New York
# Captain America     male              1941        Avengers  World War II
# Wolverine           male              1974           X-Men        Canada
# Iron Man            male              1963        Avengers      New York
# Thor                male              1963        Avengers        Asgard
# Thing               male              1961  Fantastic Four      New York
# Mister Fantastic    male              1961  Fantastic Four      New York
# Hulk                male              1962        Avengers      New York
# Beast               male              1963           X-Men      Illinois
# Invisible Woman   female              1961  Fantastic Four      New York
# Storm             female              1975           X-Men         Kenya
# Namor               male              1939           X-Men      Atlantis
# Hawkeye             male              1964        Avengers          Iowa
# Daredevil           male              1964       Defenders      New York
# Doctor Strange      male              1963       Defenders      New York
# Hank Pym            male              1962        Avengers      New York
# Scarlet Witch     female              1964        Avengers       Sokovia
# Wasp              female              1963        Avengers      New York
# Black Widow       female              1964        Avengers        Russia
# Vision              male              1968        Avengers      Synthoid
#
#                   popularity_score    status
# name
# Spider-Man                     9.8    active
# Captain America                9.6    active
# Wolverine                      9.5    active
# Iron Man                       9.7  deceased
# Thor                           9.8    active
# Thing                          8.5    active
# Mister Fantastic               8.8    active
# Hulk                           9.2    active
# Beast                          8.3    active
# Invisible Woman                8.9    active
# Storm                          9.1    active
# Namor                          7.9    active
# Hawkeye                        7.8    active
# Daredevil                      8.7    active
# Doctor Strange                 9.4    active
# Hank Pym                       8.0   retired
# Scarlet Witch                  9.3    active
# Wasp                           8.1    active
# Black Widow                    9.0  deceased
# Vision                         8.9    active

# %% [markdown]
# ---
# Let's roll it back. Let's reset name to be column not index anymore

# %%
# your code goes here

# %%
marvel_df = marvel_df.reset_index()
marvel_df
# Out:
#                 name  gender  first_appearance  \
# 0         Spider-Man    male              1962
# 1    Captain America    male              1941
# 2          Wolverine    male              1974
# 3           Iron Man    male              1963
# 4               Thor    male              1963
# 5              Thing    male              1961
# 6   Mister Fantastic    male              1961
# 7               Hulk    male              1962
# 8              Beast    male              1963
# 9    Invisible Woman  female              1961
# 10             Storm  female              1975
# 11             Namor    male              1939
# 12           Hawkeye    male              1964
# 13         Daredevil    male              1964
# 14    Doctor Strange    male              1963
# 15          Hank Pym    male              1962
# 16     Scarlet Witch  female              1964
# 17              Wasp  female              1963
# 18       Black Widow  female              1964
# 19            Vision    male              1968
#
#                                      superpower            team        origin  \
# 0                 Wall-crawling, super strength        Avengers      New York
# 1                        Super soldier strength        Avengers  World War II
# 2                           Regeneration, claws           X-Men        Canada
# 3         Genius-level intellect, powered armor        Avengers      New York
# 4                       Godly strength, Mjölnir        Avengers        Asgard
# 5                    Rocky skin, super strength  Fantastic Four      New York
# 6                                  Elastic body  Fantastic Four      New York
# 7   Super strength, rage-induced transformation        Avengers      New York
# 8                       Super strength, agility           X-Men      Illinois
# 9                    Invisibility, force fields  Fantastic Four      New York
# 10                         Weather manipulation           X-Men         Kenya
# 11                            Aquatic abilities           X-Men      Atlantis
# 12                                Expert archer        Avengers          Iowa
# 13                Enhanced senses, martial arts       Defenders      New York
# 14                        Master of mystic arts       Defenders      New York
# 15                            Size manipulation        Avengers      New York
# 16                         Reality manipulation        Avengers       Sokovia
# 17                    Size manipulation, flight        Avengers      New York
# 18                   Expert spy, martial artist        Avengers        Russia
# 19                         Density manipulation        Avengers      Synthoid
#
#     popularity_score    status
# 0                9.8    active
# 1                9.6    active
# 2                9.5    active
# 3                9.7  deceased
# 4                9.8    active
# 5                8.5    active
# 6                8.8    active
# 7                9.2    active
# 8                8.3    active
# 9                8.9    active
# 10               9.1    active
# 11               7.9    active
# 12               7.8    active
# 13               8.7    active
# 14               9.4    active
# 15               8.0   retired
# 16               9.3    active
# 17               8.1    active
# 18               9.0  deceased
# 19               8.9    active

# %% [markdown]
# ---
# create copy of current dataframe of backup
#
# ```
# backup = marvel_data.copy()

# %%
backup = marvel_data.copy()

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
#
# ## DataFrame selection, slicing and indexation

# %% [markdown]
# ---
# Show the first 4 rows on `marvel_df` using string-range indexing

# %%
# your code goes here

# %%
# marvel_df.loc[['Spider-Man', 'Captain America', 'Wolverine', 'Iron Man'], :] # okay, but not efficient!
marvel_df.loc["Spider-Man":"Iron Man", :]
# Out:
# Empty DataFrame
# Columns: [name, gender, first_appearance, superpower, team, origin, popularity_score, status]
# Index: []

# %% [markdown]
# ---
# Show the last 4 rows on `marvel_df` using tail function

# %%
# your code goes here

# %%
marvel_df.tail(4)
# Out:
#              name  gender  first_appearance                  superpower  \
# 16  Scarlet Witch  female              1964        Reality manipulation
# 17           Wasp  female              1963   Size manipulation, flight
# 18    Black Widow  female              1964  Expert spy, martial artist
# 19         Vision    male              1968        Density manipulation
#
#         team    origin  popularity_score    status
# 16  Avengers   Sokovia               9.3    active
# 17  Avengers  New York               8.1    active
# 18  Avengers    Russia               9.0  deceased
# 19  Avengers  Synthoid               8.9    active

# %% [markdown]
# ---
# Show the last 3 columns on `marvel_df` using iloc

# %%
# your code goes here

# %%
marvel_df.iloc[:, -3:]
# Out:
#           origin  popularity_score    status
# 0       New York               9.8    active
# 1   World War II               9.6    active
# 2         Canada               9.5    active
# 3       New York               9.7  deceased
# 4         Asgard               9.8    active
# 5       New York               8.5    active
# 6       New York               8.8    active
# 7       New York               9.2    active
# 8       Illinois               8.3    active
# 9       New York               8.9    active
# 10         Kenya               9.1    active
# 11      Atlantis               7.9    active
# 12          Iowa               7.8    active
# 13      New York               8.7    active
# 14      New York               9.4    active
# 15      New York               8.0   retired
# 16       Sokovia               9.3    active
# 17      New York               8.1    active
# 18        Russia               9.0  deceased
# 19      Synthoid               8.9    active

# %% [markdown]
# ---
# Show just the `gender` of the first 5 elements on `marvel_df`
# - make sure you are printing it as DATAFRAME

# %%
# your code goes here

# %%
marvel_df.iloc[:5, 0].to_frame()
# Out:
#               name
# 0       Spider-Man
# 1  Captain America
# 2        Wolverine
# 3         Iron Man
# 4             Thor

# %% [markdown]
# ---
# Show the first_appearance of all middle rows on `marvel_df`
# - make sure you are printing it as DATAFRAME

# %%
# your code goes here

# %%
marvel_df.iloc[1:-1,].first_appearance
# Out:
# 1     1941
# 2     1974
# 3     1963
# 4     1963
# 5     1961
# 6     1961
# 7     1962
# 8     1963
# 9     1961
# 10    1975
# 11    1939
# 12    1964
# 13    1964
# 14    1963
# 15    1962
# 16    1964
# 17    1963
# 18    1964
# Name: first_appearance, dtype: int64

# %% [markdown]
# ---
# Show the first and last rows on `marvel_df`

# %%
# your code goes here

# %%
marvel_df.iloc[[0, -1]]
# Out:
#           name gender  first_appearance                     superpower  \
# 0   Spider-Man   male              1962  Wall-crawling, super strength
# 19      Vision   male              1968           Density manipulation
#
#         team    origin  popularity_score  status
# 0   Avengers  New York               9.8  active
# 19  Avengers  Synthoid               8.9  active

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
#
# ## DataFrame manipulation and operations

# %% [markdown]
# ---
# Modify the `first_appearance` of 'Vision' to year 1964

# %%
# your code goes here

# %%
marvel_df.loc["Vision", "first_appearance"] = 1964
marvel_df
# Out:
#                     name  gender  first_appearance  \
# 0             Spider-Man    male            1962.0
# 1        Captain America    male            1941.0
# 2              Wolverine    male            1974.0
# 3               Iron Man    male            1963.0
# 4                   Thor    male            1963.0
# 5                  Thing    male            1961.0
# 6       Mister Fantastic    male            1961.0
# 7                   Hulk    male            1962.0
# 8                  Beast    male            1963.0
# 9        Invisible Woman  female            1961.0
# 10                 Storm  female            1975.0
# 11                 Namor    male            1939.0
# 12               Hawkeye    male            1964.0
# 13             Daredevil    male            1964.0
# 14        Doctor Strange    male            1963.0
# 15              Hank Pym    male            1962.0
# 16         Scarlet Witch  female            1964.0
# 17                  Wasp  female            1963.0
# 18           Black Widow  female            1964.0
# 19                Vision    male            1968.0
# Vision               NaN     NaN            1964.0
#
#                                          superpower            team  \
# 0                     Wall-crawling, super strength        Avengers
# 1                            Super soldier strength        Avengers
# 2                               Regeneration, claws           X-Men
# 3             Genius-level intellect, powered armor        Avengers
# 4                           Godly strength, Mjölnir        Avengers
# 5                        Rocky skin, super strength  Fantastic Four
# 6                                      Elastic body  Fantastic Four
# 7       Super strength, rage-induced transformation        Avengers
# 8                           Super strength, agility           X-Men
# 9                        Invisibility, force fields  Fantastic Four
# 10                             Weather manipulation           X-Men
# 11                                Aquatic abilities           X-Men
# 12                                    Expert archer        Avengers
# 13                    Enhanced senses, martial arts       Defenders
# 14                            Master of mystic arts       Defenders
# 15                                Size manipulation        Avengers
# 16                             Reality manipulation        Avengers
# 17                        Size manipulation, flight        Avengers
# 18                       Expert spy, martial artist        Avengers
# 19                             Density manipulation        Avengers
# Vision                                          NaN             NaN
#
#               origin  popularity_score    status
# 0           New York               9.8    active
# 1       World War II               9.6    active
# 2             Canada               9.5    active
# 3           New York               9.7  deceased
# 4             Asgard               9.8    active
# 5           New York               8.5    active
# 6           New York               8.8    active
# 7           New York               9.2    active
# 8           Illinois               8.3    active
# 9           New York               8.9    active
# 10             Kenya               9.1    active
# 11          Atlantis               7.9    active
# 12              Iowa               7.8    active
# 13          New York               8.7    active
# 14          New York               9.4    active
# 15          New York               8.0   retired
# 16           Sokovia               9.3    active
# 17          New York               8.1    active
# 18            Russia               9.0  deceased
# 19          Synthoid               8.9    active
# Vision           NaN               NaN       NaN

# %% [markdown]
# ---
# Add a new column to `marvel_df` called `years_since` with the years since `first_appearance`

# %%
# your code goes here

# %%
marvel_df["years_since"] = 2024 - marvel_df["first_appearance"]
marvel_df
# Out:
#                     name  gender  first_appearance  \
# 0             Spider-Man    male            1962.0
# 1        Captain America    male            1941.0
# 2              Wolverine    male            1974.0
# 3               Iron Man    male            1963.0
# 4                   Thor    male            1963.0
# 5                  Thing    male            1961.0
# 6       Mister Fantastic    male            1961.0
# 7                   Hulk    male            1962.0
# 8                  Beast    male            1963.0
# 9        Invisible Woman  female            1961.0
# 10                 Storm  female            1975.0
# 11                 Namor    male            1939.0
# 12               Hawkeye    male            1964.0
# 13             Daredevil    male            1964.0
# 14        Doctor Strange    male            1963.0
# 15              Hank Pym    male            1962.0
# 16         Scarlet Witch  female            1964.0
# 17                  Wasp  female            1963.0
# 18           Black Widow  female            1964.0
# 19                Vision    male            1968.0
# Vision               NaN     NaN            1964.0
#
#                                          superpower            team  \
# 0                     Wall-crawling, super strength        Avengers
# 1                            Super soldier strength        Avengers
# 2                               Regeneration, claws           X-Men
# 3             Genius-level intellect, powered armor        Avengers
# 4                           Godly strength, Mjölnir        Avengers
# 5                        Rocky skin, super strength  Fantastic Four
# 6                                      Elastic body  Fantastic Four
# 7       Super strength, rage-induced transformation        Avengers
# 8                           Super strength, agility           X-Men
# 9                        Invisibility, force fields  Fantastic Four
# 10                             Weather manipulation           X-Men
# 11                                Aquatic abilities           X-Men
# 12                                    Expert archer        Avengers
# 13                    Enhanced senses, martial arts       Defenders
# 14                            Master of mystic arts       Defenders
# 15                                Size manipulation        Avengers
# 16                             Reality manipulation        Avengers
# 17                        Size manipulation, flight        Avengers
# 18                       Expert spy, martial artist        Avengers
# 19                             Density manipulation        Avengers
# Vision                                          NaN             NaN
#
#               origin  popularity_score    status  years_since
# 0           New York               9.8    active         62.0
# 1       World War II               9.6    active         83.0
# 2             Canada               9.5    active         50.0
# 3           New York               9.7  deceased         61.0
# 4             Asgard               9.8    active         61.0
# 5           New York               8.5    active         63.0
# 6           New York               8.8    active         63.0
# 7           New York               9.2    active         62.0
# 8           Illinois               8.3    active         61.0
# 9           New York               8.9    active         63.0
# 10             Kenya               9.1    active         49.0
# 11          Atlantis               7.9    active         85.0
# 12              Iowa               7.8    active         60.0
# 13          New York               8.7    active         60.0
# 14          New York               9.4    active         61.0
# 15          New York               8.0   retired         62.0
# 16           Sokovia               9.3    active         60.0
# 17          New York               8.1    active         61.0
# 18            Russia               9.0  deceased         60.0
# 19          Synthoid               8.9    active         56.0
# Vision           NaN               NaN       NaN         60.0

# %% [markdown]
# ---
# Given the `marvel_df` pandas DataFrame, make a mask showing the female characters - just show mask

# %%
# your code goes here

# %%
mask = marvel_df["gender"] == "female"
mask
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
# 5         False
# 6         False
# 7         False
# 8         False
# 9          True
# 10         True
# 11        False
# 12        False
# 13        False
# 14        False
# 15        False
# 16         True
# 17         True
# 18         True
# 19        False
# Vision    False
# Name: gender, dtype: bool

# %% [markdown]
# ---
# Given the `marvel_df` pandas DataFrame, get the characters with `first_appearance` after 1970 - show filtered result

# %%
# your code goes here

# %%
mask = marvel_df["first_appearance"] > 1970
marvel_df[mask]
# Out:
#          name  gender  first_appearance            superpower   team  origin  \
# 2   Wolverine    male            1974.0   Regeneration, claws  X-Men  Canada
# 10      Storm  female            1975.0  Weather manipulation  X-Men   Kenya
#
#     popularity_score  status  years_since
# 2                9.5  active         50.0
# 10               9.1  active         49.0

# %% [markdown]
# ---
# Given the `marvel_df` pandas DataFrame, get the characters with `first_appearance` is NOT 1970 - show filtered result

# %%
# your code goes here

# %%
mask = (marvel_df["gender"] == "male") & (marvel_df["first_appearance"] != 1970)
marvel_df[mask]
# Out:
#                 name gender  first_appearance  \
# 0         Spider-Man   male            1962.0
# 1    Captain America   male            1941.0
# 2          Wolverine   male            1974.0
# 3           Iron Man   male            1963.0
# 4               Thor   male            1963.0
# 5              Thing   male            1961.0
# 6   Mister Fantastic   male            1961.0
# 7               Hulk   male            1962.0
# 8              Beast   male            1963.0
# 11             Namor   male            1939.0
# 12           Hawkeye   male            1964.0
# 13         Daredevil   male            1964.0
# 14    Doctor Strange   male            1963.0
# 15          Hank Pym   male            1962.0
# 19            Vision   male            1968.0
#
#                                      superpower            team        origin  \
# 0                 Wall-crawling, super strength        Avengers      New York
# 1                        Super soldier strength        Avengers  World War II
# 2                           Regeneration, claws           X-Men        Canada
# 3         Genius-level intellect, powered armor        Avengers      New York
# 4                       Godly strength, Mjölnir        Avengers        Asgard
# 5                    Rocky skin, super strength  Fantastic Four      New York
# 6                                  Elastic body  Fantastic Four      New York
# 7   Super strength, rage-induced transformation        Avengers      New York
# 8                       Super strength, agility           X-Men      Illinois
# 11                            Aquatic abilities           X-Men      Atlantis
# 12                                Expert archer        Avengers          Iowa
# 13                Enhanced senses, martial arts       Defenders      New York
# 14                        Master of mystic arts       Defenders      New York
# 15                            Size manipulation        Avengers      New York
# 19                         Density manipulation        Avengers      Synthoid
#
#     popularity_score    status  years_since
# 0                9.8    active         62.0
# 1                9.6    active         83.0
# 2                9.5    active         50.0
# 3                9.7  deceased         61.0
# 4                9.8    active         61.0
# 5                8.5    active         63.0
# 6                8.8    active         63.0
# 7                9.2    active         62.0
# 8                8.3    active         61.0
# 11               7.9    active         85.0
# 12               7.8    active         60.0
# 13               8.7    active         60.0
# 14               9.4    active         61.0
# 15               8.0   retired         62.0
# 19               8.9    active         56.0

# %% [markdown]
# ---
# Convert a gender column to have 'M' and 'F' instead of 'male' and 'female'
# - use replace

# %%
# your code goes here

# %%
marvel_df["gender"] = marvel_df["gender"].replace({"male": "M", "female": "F"})
marvel_df
# Out:
#                     name gender  first_appearance  \
# 0             Spider-Man      M            1962.0
# 1        Captain America      M            1941.0
# 2              Wolverine      M            1974.0
# 3               Iron Man      M            1963.0
# 4                   Thor      M            1963.0
# 5                  Thing      M            1961.0
# 6       Mister Fantastic      M            1961.0
# 7                   Hulk      M            1962.0
# 8                  Beast      M            1963.0
# 9        Invisible Woman      F            1961.0
# 10                 Storm      F            1975.0
# 11                 Namor      M            1939.0
# 12               Hawkeye      M            1964.0
# 13             Daredevil      M            1964.0
# 14        Doctor Strange      M            1963.0
# 15              Hank Pym      M            1962.0
# 16         Scarlet Witch      F            1964.0
# 17                  Wasp      F            1963.0
# 18           Black Widow      F            1964.0
# 19                Vision      M            1968.0
# Vision               NaN    NaN            1964.0
#
#                                          superpower            team  \
# 0                     Wall-crawling, super strength        Avengers
# 1                            Super soldier strength        Avengers
# 2                               Regeneration, claws           X-Men
# 3             Genius-level intellect, powered armor        Avengers
# 4                           Godly strength, Mjölnir        Avengers
# 5                        Rocky skin, super strength  Fantastic Four
# 6                                      Elastic body  Fantastic Four
# 7       Super strength, rage-induced transformation        Avengers
# 8                           Super strength, agility           X-Men
# 9                        Invisibility, force fields  Fantastic Four
# 10                             Weather manipulation           X-Men
# 11                                Aquatic abilities           X-Men
# 12                                    Expert archer        Avengers
# 13                    Enhanced senses, martial arts       Defenders
# 14                            Master of mystic arts       Defenders
# 15                                Size manipulation        Avengers
# 16                             Reality manipulation        Avengers
# 17                        Size manipulation, flight        Avengers
# 18                       Expert spy, martial artist        Avengers
# 19                             Density manipulation        Avengers
# Vision                                          NaN             NaN
#
#               origin  popularity_score    status  years_since
# 0           New York               9.8    active         62.0
# 1       World War II               9.6    active         83.0
# 2             Canada               9.5    active         50.0
# 3           New York               9.7  deceased         61.0
# 4             Asgard               9.8    active         61.0
# 5           New York               8.5    active         63.0
# 6           New York               8.8    active         63.0
# 7           New York               9.2    active         62.0
# 8           Illinois               8.3    active         61.0
# 9           New York               8.9    active         63.0
# 10             Kenya               9.1    active         49.0
# 11          Atlantis               7.9    active         85.0
# 12              Iowa               7.8    active         60.0
# 13          New York               8.7    active         60.0
# 14          New York               9.4    active         61.0
# 15          New York               8.0   retired         62.0
# 16           Sokovia               9.3    active         60.0
# 17          New York               8.1    active         61.0
# 18            Russia               9.0  deceased         60.0
# 19          Synthoid               8.9    active         56.0
# Vision           NaN               NaN       NaN         60.0

# %% [markdown]
# ---
# Let's roll it back. Convert a gender column to have 'male' and 'female'
# - use masking

# %%
# your code goes here

# %%
marvel_df.loc[marvel_df["gender"] == "F", "gender"] = "female"
marvel_df.loc[marvel_df["gender"] == "M", "gender"] = "male"
marvel_df
# Out:
#                     name  gender  first_appearance  \
# 0             Spider-Man    male            1962.0
# 1        Captain America    male            1941.0
# 2              Wolverine    male            1974.0
# 3               Iron Man    male            1963.0
# 4                   Thor    male            1963.0
# 5                  Thing    male            1961.0
# 6       Mister Fantastic    male            1961.0
# 7                   Hulk    male            1962.0
# 8                  Beast    male            1963.0
# 9        Invisible Woman  female            1961.0
# 10                 Storm  female            1975.0
# 11                 Namor    male            1939.0
# 12               Hawkeye    male            1964.0
# 13             Daredevil    male            1964.0
# 14        Doctor Strange    male            1963.0
# 15              Hank Pym    male            1962.0
# 16         Scarlet Witch  female            1964.0
# 17                  Wasp  female            1963.0
# 18           Black Widow  female            1964.0
# 19                Vision    male            1968.0
# Vision               NaN     NaN            1964.0
#
#                                          superpower            team  \
# 0                     Wall-crawling, super strength        Avengers
# 1                            Super soldier strength        Avengers
# 2                               Regeneration, claws           X-Men
# 3             Genius-level intellect, powered armor        Avengers
# 4                           Godly strength, Mjölnir        Avengers
# 5                        Rocky skin, super strength  Fantastic Four
# 6                                      Elastic body  Fantastic Four
# 7       Super strength, rage-induced transformation        Avengers
# 8                           Super strength, agility           X-Men
# 9                        Invisibility, force fields  Fantastic Four
# 10                             Weather manipulation           X-Men
# 11                                Aquatic abilities           X-Men
# 12                                    Expert archer        Avengers
# 13                    Enhanced senses, martial arts       Defenders
# 14                            Master of mystic arts       Defenders
# 15                                Size manipulation        Avengers
# 16                             Reality manipulation        Avengers
# 17                        Size manipulation, flight        Avengers
# 18                       Expert spy, martial artist        Avengers
# 19                             Density manipulation        Avengers
# Vision                                          NaN             NaN
#
#               origin  popularity_score    status  years_since
# 0           New York               9.8    active         62.0
# 1       World War II               9.6    active         83.0
# 2             Canada               9.5    active         50.0
# 3           New York               9.7  deceased         61.0
# 4             Asgard               9.8    active         61.0
# 5           New York               8.5    active         63.0
# 6           New York               8.8    active         63.0
# 7           New York               9.2    active         62.0
# 8           Illinois               8.3    active         61.0
# 9           New York               8.9    active         63.0
# 10             Kenya               9.1    active         49.0
# 11          Atlantis               7.9    active         85.0
# 12              Iowa               7.8    active         60.0
# 13          New York               8.7    active         60.0
# 14          New York               9.4    active         61.0
# 15          New York               8.0   retired         62.0
# 16           Sokovia               9.3    active         60.0
# 17          New York               8.1    active         61.0
# 18            Russia               9.0  deceased         60.0
# 19          Synthoid               8.9    active         56.0
# Vision           NaN               NaN       NaN         60.0

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
#
# ## DataFrame summary statistics

# %% [markdown]
# ---
# Show basic statistics summary of `marvel_df`

# %%
# your code goes here

# %%
marvel_df.first_appearance.mean()
# Out:
# 1961.952380952381

# %% [markdown]
# ---
# Given the `marvel_df` pandas DataFrame, show each count of character's origin
# - you will know how many people are from New york, Asgard, Iowa etc

# %%
# your code goes here

# %%
marvel_df.origin.value_counts()
# Out:
# origin
# New York        10
# World War II     1
# Canada           1
# Asgard           1
# Illinois         1
# Kenya            1
# Atlantis         1
# Iowa             1
# Sokovia          1
# Russia           1
# Synthoid         1
# Name: count, dtype: int64

# %% [markdown]
# ---
# Given the `marvel_df` pandas DataFrame, show the minimum and mean value of `first_appearance`

# %%
# your code goes here

# %%
print(marvel_df.first_appearance.mean())
print(marvel_df.first_appearance.min())
# Out:
# 1961.952380952381
# 1939.0

# %% [markdown]
# ---
# Given the `marvel_df` pandas DataFrame, show the min value of `first_appearance`

# %%
# your code goes here

# %%
marvel_df.first_appearance.min()
# Out:
# 1939.0

# %% [markdown]
# ---
# Given the `marvel_df` pandas DataFrame, consider the conditions.
# - first_appearance is before 1969(not including 1969)
# - male
# - team name not Fantastic Four
#
# And find:
# - find how many characters are qualified
# - find their average of popularity score

# %%
# your code goes here

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
#
# ## DataFrame basic plottings

# %% [markdown]
# ---
# Bar-Plot the value count of `first_appearance`
# - your plot must show there are 5 characters in 1963, 3 characters in 1962 etc

# %%
# your code goes here

# %%
marvel_df.first_appearance.value_counts().to_frame().plot(kind="bar")
# Out:
# <Axes: xlabel='first_appearance'>

# %% [markdown]
# ---
# Bar-Plot the value count of `team`
# - your plot must show there are 11 Avengers, 4 X-men etc

# %%
# your code goes here

# %%
marvel_df.team.value_counts().to_frame().plot(kind="bar", grid=True)
# Out:
# <Axes: xlabel='team'>
