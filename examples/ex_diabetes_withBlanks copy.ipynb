# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
# # Diabetes - From Sklearn Dataset

# %% [markdown]
# ### Q: import diabetes data, and...
# - read description to see what the target is, what features we have.
# - is target categorical? or numerical?
# - what does each target represent? eg: bp, s1, s2.. ??????

# %%
# your code goes here
from sklearn.datasets import load_diabetes

diabetes = load_diabetes()

x_data = diabetes.data
y_data = diabetes.target
print(diabetes.DESCR)
# Out:
# .. _diabetes_dataset:
#
# Diabetes dataset
# ----------------
#
# Ten baseline variables, age, sex, body mass index, average blood
# pressure, and six blood serum measurements were obtained for each of n =
# 442 diabetes patients, as well as the response of interest, a
# quantitative measure of disease progression one year after baseline.
#
# **Data Set Characteristics:**
#
#   :Number of Instances: 442
#
#   :Number of Attributes: First 10 columns are numeric predictive values
#
#   :Target: Column 11 is a quantitative measure of disease progression one year after baseline
#
#   :Attribute Information:
#       - age     age in years
#       - sex
#       - bmi     body mass index
#       - bp      average blood pressure
#       - s1      tc, total serum cholesterol
#       - s2      ldl, low-density lipoproteins
#       - s3      hdl, high-density lipoproteins
#       - s4      tch, total cholesterol / HDL
#       - s5      ltg, possibly log of serum triglycerides level
#       - s6      glu, blood sugar level
#
# Note: Each of these 10 feature variables have been mean centered and scaled by the standard deviation times the square root of `n_samples` (i.e. the sum of squares of each column totals 1).
#
# Source URL:
# https://www4.stat.ncsu.edu/~boos/var.select/diabetes.html
#
# For more information see:
# Bradley Efron, Trevor Hastie, Iain Johnstone and Robert Tibshirani (2004) "Least Angle Regression," Annals of Statistics (with discussion), 407-499.
# (https://web.stanford.edu/~hastie/Papers/LARS/LeastAngle_2002.pdf)

# %%
# your code goes here
diabetes.feature_names
# Out:
# ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']

# %% [markdown]
# Attribute Information:
#
#     - age     age in years
#     - sex
#     - bmi     body mass index
#     - bp      average blood pressure
#     - s1      tc, total serum cholesterol
#     - s2      ldl, low-density lipoproteins
#     - s3      hdl, high-density lipoproteins
#     - s4      tch, total cholesterol / HDL
#     - s5      ltg, possibly log of serum triglycerides level
#     - s6      glu, blood sugar level

# %% [markdown]
# ### Q convert sklearn data to pandas dataframe.
# - add target column to the rightmost
# - at the end, you must have N by 11 dataframe

# %%
# your code goes here
df = pd.DataFrame(diabetes.data)
df.columns = diabetes.feature_names
df["target"] = diabetes.target
df
# Out:
#           age       sex       bmi        bp        s1        s2        s3  \
# 0    0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1   -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2    0.085299  0.050680  0.044451 -0.005670 -0.045599 -0.034194 -0.032356
# 3   -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4    0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
# ..        ...       ...       ...       ...       ...       ...       ...
# 437  0.041708  0.050680  0.019662  0.059744 -0.005697 -0.002566 -0.028674
# 438 -0.005515  0.050680 -0.015906 -0.067642  0.049341  0.079165 -0.028674
# 439  0.041708  0.050680 -0.015906  0.017293 -0.037344 -0.013840 -0.024993
# 440 -0.045472 -0.044642  0.039062  0.001215  0.016318  0.015283 -0.028674
# 441 -0.045472 -0.044642 -0.073030 -0.081413  0.083740  0.027809  0.173816
#
#            s4        s5        s6  target
# 0   -0.002592  0.019907 -0.017646   151.0
# 1   -0.039493 -0.068332 -0.092204    75.0
# 2   -0.002592  0.002861 -0.025930   141.0
# 3    0.034309  0.022688 -0.009362   206.0
# 4   -0.002592 -0.031988 -0.046641   135.0
# ..        ...       ...       ...     ...
# 437 -0.002592  0.031193  0.007207   178.0
# 438  0.034309 -0.018114  0.044485   104.0
# 439 -0.011080 -0.046883  0.015491   132.0
# 440  0.026560  0.044529 -0.025930   220.0
# 441 -0.039493 -0.004222  0.003064    57.0
#
# [442 rows x 11 columns]

# %% [markdown]
# ### Q. Using pandas, check short summary of your dataframe then answer below
# - any null value? if so, how can we replace this?
# - how age can be 0.038076, -0.01882?
# - how sex can be 0.050680 ?

# %%
# your code goes here
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 442 entries, 0 to 441
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   age     442 non-null    float64
#  1   sex     442 non-null    float64
#  2   bmi     442 non-null    float64
#  3   bp      442 non-null    float64
#  4   s1      442 non-null    float64
#  5   s2      442 non-null    float64
#  6   s3      442 non-null    float64
#  7   s4      442 non-null    float64
#  8   s5      442 non-null    float64
#  9   s6      442 non-null    float64
#  10  target  442 non-null    float64
# dtypes: float64(11)
# memory usage: 38.1 KB

# %%
# your code goes here

# %% [markdown]
# ### Q how many male and female do we have?

# %%
# your code goes here
df["sex"].value_counts()
# Out:
# sex
# -0.044642    235
#  0.050680    207
# Name: count, dtype: int64

# %% [markdown]
# ### Q. plot histogram of age, bmi, and bp
# - using subplot of 1 row, 3 columns
# - you can set bin-count on your decision
# - is it follow normal distribution?

# %%
# your code goes here
plt.figure(figsize=(15, 5))

plt.subplot(1, 3, 1)
plt.hist(df["age"], bins=5)
plt.title("age")
plt.ylabel("count")

plt.subplot(1, 3, 2)
plt.hist(df["bmi"], bins=5)
plt.xlabel("bmi(cm/kg^2)")
plt.ylabel("count")

plt.subplot(1, 3, 3)
plt.hist(df["bp"], bins=5)
plt.tight_layout()

# %%
# your code goes here
plt.figure(figsize=(15, 5))

plt.subplot(1, 3, 1)
sns.histplot(df["age"], bins=8, kde=True)

plt.subplot(1, 3, 2)
sns.histplot(df["bmi"], bins=8, kde=True)

plt.subplot(1, 3, 3)
sns.histplot(df["bp"], bins=8)
# Out:
# <Axes: xlabel='bp', ylabel='Count'>

# %% [markdown]
# #### FYI, you can plot histogram of all features at once
# ````python
# df.hist(bins=20, figsize=(12, 6))
# plt.tight_layout()
# plt.show()

# %%
df.hist(bins=8, figsize=(12, 6))
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Q: Are there any outliers? Are the features well scaled?
# - What kind of plot is the easiest way to check?
# - Are the features scaled using Min-Max scaling or Standard scaling?

# %%
sns.boxplot(data=df.iloc[:, :-1], orient="v")
plt.title("Box plot")
plt.xticks(rotation=45)
plt.show()

# %%
sns.violinplot(data=df.iloc[:, :-1], orient="v")
plt.title("Box plot")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### Q check relationships between each feauture

# %%
sns.pairplot(df.loc[:, ["bmi", "bp", "age", "target", "s6"]])

# %% [markdown]
# #### FYI you can also try heatmap

# %%
df.corr()
# Out:
#              age       sex       bmi        bp        s1        s2        s3  \
# age     1.000000  0.173737  0.185085  0.335428  0.260061  0.219243 -0.075181
# sex     0.173737  1.000000  0.088161  0.241010  0.035277  0.142637 -0.379090
# bmi     0.185085  0.088161  1.000000  0.395411  0.249777  0.261170 -0.366811
# bp      0.335428  0.241010  0.395411  1.000000  0.242464  0.185548 -0.178762
# s1      0.260061  0.035277  0.249777  0.242464  1.000000  0.896663  0.051519
# s2      0.219243  0.142637  0.261170  0.185548  0.896663  1.000000 -0.196455
# s3     -0.075181 -0.379090 -0.366811 -0.178762  0.051519 -0.196455  1.000000
# s4      0.203841  0.332115  0.413807  0.257650  0.542207  0.659817 -0.738493
# s5      0.270774  0.149916  0.446157  0.393480  0.515503  0.318357 -0.398577
# s6      0.301731  0.208133  0.388680  0.390430  0.325717  0.290600 -0.273697
# target  0.187889  0.043062  0.586450  0.441482  0.212022  0.174054 -0.394789
#
#               s4        s5        s6    target
# age     0.203841  0.270774  0.301731  0.187889
# sex     0.332115  0.149916  0.208133  0.043062
# bmi     0.413807  0.446157  0.388680  0.586450
# bp      0.257650  0.393480  0.390430  0.441482
# s1      0.542207  0.515503  0.325717  0.212022
# s2      0.659817  0.318357  0.290600  0.174054
# s3     -0.738493 -0.398577 -0.273697 -0.394789
# s4      1.000000  0.617859  0.417212  0.430453
# s5      0.617859  1.000000  0.464669  0.565883
# s6      0.417212  0.464669  1.000000  0.382483
# target  0.430453  0.565883  0.382483  1.000000

# %%
# your code goes here
sns.heatmap(df.corr(), annot=True, vmax=1, vmin=-1, cmap="coolwarm")
# Out:
# <Axes: >

# %% [markdown]
# ### Plot scatter of subplots of 1-row 2-columns
# - bmi vs target,
# - bp vs target
#
# start with plt.figure(figsize=(12,5))

# %% [markdown]
# ### Q Do linear regression of each - Single/Simple linear regression
#
# hint:
# - print slope and interceet for each.
# - you need to create two differant models for `bmi vs target` and `bp vs target`
# - you do not need to re-import load-diabetes again. Use existing dataframe
# - don't forget to `train-test-split`, because we need to calculate the score later

# %%
# your code goes here
y = df["target"]
X1 = df["bmi"]
X2 = df["bp"]

# %%
from sklearn.model_selection import train_test_split

X1_train, X1_test, X2_train, X2_test, y_train, y_test = train_test_split(X1, X2, y)

# %%
from sklearn.linear_model import LinearRegression

model1 = LinearRegression()
model1.fit(X1_train.values.reshape(-1, 1), y_train)

print("Result of BMI vs Target")
print("Slope(Beta):", model1.coef_[0])
print("Intercept:", model1.intercept_)
# Out:
# Result of BMI vs Target
# Slope(Beta): 944.0186542499238
# Intercept: 152.04184686554507

# %%
from sklearn.linear_model import LinearRegression

model2 = LinearRegression()
model2.fit(X2_train.values.reshape(-1, 1), y_train)

print("Result of BP vs Target")
print("Slope(Beta):", model2.coef_[0])
print("Intercept:", model2.intercept_)
# Out:
# Result of BP vs Target
# Slope(Beta): 705.398252694827
# Intercept: 150.7651504609558

# %% [markdown]
# ### Q then plot trend-line for each
# - set title to show equation: $y=ax+b$

# %%
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.scatter(x="bmi", y="target", data=df)
plt.plot(
    X1_train, model1.predict(X1_train.values.reshape(-1, 1)), color="red", linewidth=2
)
plt.xlabel("BMI")
plt.ylabel("Progression of Diabetes")
plt.title(f"y={model1.coef_[0].round(1)}x + {model1.intercept_.round(1)}")
plt.xlim([-0.1, 0.2])

plt.subplot(1, 2, 2)
plt.scatter(x="bp", y="target", data=df)
plt.plot(
    X2_train, model2.predict(X2_train.values.reshape(-1, 1)), color="red", linewidth=2
)
plt.xlim([-0.2, 0.2])
plt.xlabel("BP")
plt.ylabel("Progression of Diabetes")
plt.title(f"y={model2.coef_[0].round(1)}x + {model2.intercept_.round(1)}")

plt.tight_layout()
plt.show()

# %% [markdown]
# #### FYI: you can draw regression plot using seaborn module easily

# %%
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
sns.regplot(data=df, x="bmi", y="target")
plt.subplot(1, 2, 2)
sns.regplot(data=df, x="bp", y="target")
# Out:
# <Axes: xlabel='bp', ylabel='target'>

# %% [markdown]
# #### FYI: you can draw two differant regression plots togather

# %%
plt.scatter(x="bmi", y="target", data=df, label="bmi vs target")
plt.plot(
    X1_train,
    model1.predict(X1_train.values.reshape(-1, 1)),
    color="blue",
    linewidth=2,
    label=f"y={model1.coef_[0].round(1)}x + {model1.intercept_.round(1)}",
)

plt.scatter(x="bp", y="target", data=df, label="bp vs target")
plt.plot(
    X2_train,
    model2.predict(X2_train.values.reshape(-1, 1)),
    color="red",
    linewidth=2,
    label=f"y={model2.coef_[0].round(1)}x + {model2.intercept_.round(1)}",
)

plt.legend()
plt.legend(loc="upper left", bbox_to_anchor=(1, 1))  # 오른쪽 위 플롯 바깥으로 이동

plt.ylabel("Progression of Diabetes")
plt.xlabel("feature values")

plt.show()

# %% [markdown]
# ### Q Calculate the score
# - model.score()
# - mean square error
# - r2_score
#
# hint:
# ```python
# from sklearn.metrics import mean_squared_error, r2_score

# %%
model1.score(X1_test.values.reshape(-1, 1), y_test)
# Out:
# 0.32634269669569627

# %%
model2.score(X2_test.values.reshape(-1, 1), y_test)
# Out:
# 0.2010886255353732

# %%
from sklearn.metrics import mean_squared_error

y_pred1 = model1.predict(X1_test.values.reshape(-1, 1))
mse_bmi = mean_squared_error(y_test, y_pred1)

y_pred2 = model2.predict(X2_test.values.reshape(-1, 1))
mse_bp = mean_squared_error(y_test, y_pred2)

mse_bmi, mse_bp
# Out:
# (3838.0050473646916, 4551.610845087549)

# %%
# your code goes here

# %% [markdown]
# ## We can improve the score! Let's do multi-regression

# %% [markdown]
# ### redefine target and feature

# %%
# your code goes here

# %% [markdown]
# ### on your own

# %%
# your code goes here

# %%
# your code goes here

# %%
# your code goes here

# %% [markdown]
# ### Q. what does increased-R-Square-score tell us?
# - will multi-regression R2 always result higher?

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
#
# # Diabetes - From Kaggle
#
# [data source](https://www.kaggle.com/uciml/pima-indians-diabetes-database)

# %%
# your code goes here

# %%
# your code goes here

# %% [markdown]
# ### Q. any null values?
# - if so, how can we handle this?
